# %%
import pandas as pd

# %%
test3 = pd.read_csv("kf_test_317.csv")

# %%
test10 = pd.read_csv('kfeatures.csv')

# %%
test10
# Out:
#        productListName  localProductPrice eventInfo.eventCategory   type  \
# 0             Category                0.0      Enhanced Ecommerce  EVENT
# 1             Category                0.0                     NaN   PAGE
# 2             Category                0.0      Enhanced Ecommerce  EVENT
# 3             Category                0.0                     NaN   PAGE
# 4             Category                0.0      Enhanced Ecommerce  EVENT
# ...                ...                ...                     ...    ...
# 119371        Category                0.0                     NaN   PAGE
# 119372        Category                0.0      Enhanced Ecommerce  EVENT
# 119373        Category                0.0                     NaN   PAGE
# 119374        Category                0.0      Enhanced Ecommerce  EVENT
# 119375             NaN                NaN      Enhanced Ecommerce  EVENT
#
#         path_depth  eCommerceAction.step  productPrice  pageviews  \
# ...

# %%
test3
# Out:
#       productListName  localProductPrice   type  productPrice  pageviews  \
# 0            Category                  0  EVENT      99990000         11
# 1            Category                  0   PAGE      99990000         11
# 2            Category                  0   PAGE      10990000          8
# 3            Category                  0  EVENT      10990000          8
# 4            Category                  0   PAGE     109990000         37
# ...               ...                ...    ...           ...        ...
# 35144        Category                  0  EVENT       8990000         15
# 35145       (not set)            8990000  EVENT       8990000         15
# 35146        Category                  0  EVENT      12990000         15
# 35147        Category                  0   PAGE      12990000         15
# 35148       (not set)           12990000  EVENT      12990000         15
#
#        is_addtocart  path_depth  \
# 0                 0           4
# ...
